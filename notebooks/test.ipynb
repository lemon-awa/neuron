# %%
import json
import numpy as np

file_name = "../python/assets/merged_with_alias_with_flywire_features.json"

with open(file_name, 'r') as f:
    data = json.load(f)

filter_data = np.random.choice([item for item in data if item['matched_by'] == 'none'], size=100)

for item in filter_data:
   print(item['cell_type'])
# Out:
# aMe3
# RP5
# Tm13
# PFx3
# CRY+ LNd
# FSB neuron
# FMIn
# labellar MSN
# Lcnn2a neuron
# β′2p DAN
# αTi-tadm
# 5th-LaN
# TmY
# SAG
# D2 medium spiny neuron
# aDN3
# SMPpv1
# Dilp 1L
# MBON-γ1γ2
# TD neuron
# PTS
# LCN6 neuron
# EB neuron
# DM5 OSN
# R2 EB neuron
# EGpost
# AMMC-8
# Sm⇒MeTu1⇒Tm35
# IPC
# AWCON
# A03a4
# Idun3
# α’β’ KC
# CQ2
# L2 IT ENTm
# M6 MBON
# at4B
# pR8
# VA2 ORN
# pEC2
# ORN
# NotchOFF neuron
# ddaF neuron
# LH output neuron
# Mi neuron
# Or65b
# DN1pB
# dorsal bipolar dendrite (dbd) proprioceptive neuron
# DN3_5
# Or46a
# BM-dPoOr
# clubround
# MB-MP1 neuron
# 19Aa
# Compass
# M4 MN
# m-NSCDMS
# A31k
# VA2 PN
# DALv2 R
# Lin A/15 MN
# LHAV1a1#1
# aMe17a
# LHPD5d1
# Runt+ neuron
# I-a bitter neuron
# PFL3L
# AVE
# Fru+ NPF neuron
# MC61 neuron
# cPVM
# FBN
# DM1 olfactory neuron
# γ5 DAN
# α′/β′ neuron
# AMMC-16
# BLA neuron
# 1s motor neuron
# MBON-γ1γ2
# Or22a ORN
# HuginVNC neuron
# PFN neuron
# SAC
# PDF sLNv
# PNs
# TH-D' neuron
# Fdg neuron
# PVLP076
# ...

# %%
import json
import random
import numpy as np
file_name = "../python/assets/outputs/merged_with_alias_and_community_and_flywire_and_neuprint.json"
with open(file_name, 'r') as f:
    data = json.load(f)

filter_data = []
for item in data:
   if item['found_in_neuprint'] == False and item['found_in_flywire'] == False:
      filter_data.append(item['cell_type'])

rst = np.random.choice(filter_data, size=100)
print(rst)
# Out:
# ['AMMC' 'FMFRaG6P neuron' 'dNPF neuron' 'E-PG4' 'v’pda-v’es2 neuron'
#  'LPi10' 'DL ORN' 'A02h' 'LC10' 'abx(3)' 'Doublescoop' 'β′2 m' 'PV5g1/g2'
#  'MN-LT2' 'M6/MBON-γ5β′2a' 'kelp' 'Ppk23+ neuron' 'Sm interneuron' 'ExFl2'
#  'ab5 ORN' 'Class 4 Toy/D neuron' 'CLI2' 'DA2-PN' 'EL interneuron' 'DNg25'
#  'APN1' 'PAM4' 'VA2 ORN' 'IGL1-OA' 'L2 neuron' 'ER5' 'lLNv neuron'
#  'b2 motoneuron' 'RP motor neuron' 'BM-Vt' 'AVD' 'RP5' 'LPi1-LPLC2'
#  'Or98a ORN' 'tra1 aSP-f' 'Munin 2' 'AMMC-2' 'PLP231' 'aDT-a PN'
#  'PPL1-γ1pedc;α2α′2' 'MB-V2α′/MBON-α′3' 'Dimm+ PI NS' 'ab9A' 'A3 v′td2'
#  'hugin neuron' 'DA1 PN' 'AMMC-VLP AV4' 'CII' 'AMMC-13' 'DCH'
#  'lateral olfactory projection neuron' 'ventral da neuron' 'ALPN3' 'iIN-1'
#  'PAM-γ5(da)' 'DC1 neuron' 'Lobula Plate Tangential Cell' 'DA-WED'
#  'Lim3+ RP motorneuron' 'DL3 lPN' 'DA neuron' 'LNv neuron' 'PVDR'
#  'ddaA neuron' 'MB-MP1 DA neuron' 'LHN PD2a1/b1' 'N-44-Glut' 'AV3' 'Gr43a'
# ...
